# %%
#################################################################################################################
###Example of script used for heatmap comparision by pixel presence in the heatmap - Scene A - original image ###
#################################################################################################################

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('original_sceneA.PNG')


grid_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20,8))
plt.imshow(grid_RGB) # Printing the original picture


grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower1_red = np.array([0, 40, 40])
upper1_red = np.array([23, 255, 255])


lower2_red = np.array([160,40,40])
upper2_red = np.array([179,255,255])

lower_mask = cv2.inRange(grid_HSV, lower1_red, upper1_red)
upper_mask = cv2.inRange(grid_HSV, lower2_red, upper2_red)

mask=lower_mask + upper_mask;

res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the red part

print("Red Part of Image (-40 dBm)")
plt.figure(figsize=(20,8))
plt.imshow(res)

RED_perc = (mask>0).mean()
print(RED_perc)
# Out:
# Red Part of Image (-40 dBm)
# 0.2905027676967631

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower_yellow = np.array([23, 93, 0])
upper_yellow = np.array([33, 255, 255])

mask= cv2.inRange(grid_HSV, lower_yellow, upper_yellow)
res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the yellow part

print("yellow Part of Image (-50 dBm)")
plt.figure(figsize=(20,8))
plt.imshow(res)

yellow_perc = (mask>0).mean()
print(yellow_perc)
# Out:
# yellow Part of Image (-50 dBm)
# 0.08065269987902782

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower_green = np.array([33, 40, 40])
upper_green = np.array([80, 255, 255])

mask= cv2.inRange(grid_HSV, lower_green, upper_green)
res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the green part

print("green Part of Image (-60 dBm)")
plt.figure(figsize=(20,8))
plt.imshow(res)

GREEN_perc = (mask>0).mean()
print(GREEN_perc)
# Out:
# green Part of Image (-60 dBm)
# 0.3116133289343451

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower_tyrkys = np.array([80, 40, 40])
upper_tyrkys = np.array([98, 255, 255])

mask= cv2.inRange(grid_HSV, lower_tyrkys, upper_tyrkys)
res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the tyrkys part

print("tyrkys Part of Image  (-70 dBm)")
plt.figure(figsize=(20,8))
plt.imshow(res)

tyrkys_perc = (mask>0).mean()
print(tyrkys_perc)
# Out:
# tyrkys Part of Image  (-70 dBm)
# 0.039105172476996956

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower_blue = np.array([98, 40, 40])
upper_blue = np.array([130, 255, 255])

mask= cv2.inRange(grid_HSV, lower_blue, upper_blue)
res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the blue part

print("blue Part of Image (-80 dBm)")
plt.figure(figsize=(20,8))
plt.imshow(res)

BLUE_perc = (mask>0).mean()
print(BLUE_perc)
# Out:
# blue Part of Image (-80 dBm)
# 0.052279225778071044

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower_violet = np.array([130, 40, 40])
upper_violet = np.array([160, 255, 255])

mask= cv2.inRange(grid_HSV, lower_violet, upper_violet)
res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the violet part

print("violet Part of Image (-90 dBm)")
plt.figure(figsize=(20,8))
plt.imshow(res)

violet_perc = (mask>0).mean()
print(violet_perc)
# Out:
# violet Part of Image (-90 dBm)
# 0.0018604054400821145

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower_violet = np.array([160, 40, 40])
upper_violet = np.array([165, 255, 255])

mask= cv2.inRange(grid_HSV, lower_violet, upper_violet)
res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the pink part

print("pink Part of Image (-100 dBm)")
plt.figure(figsize=(20,8))
plt.imshow(res)

violet_perc = (mask>0).mean()
print(violet_perc)
# Out:
# pink Part of Image (-100 dBm)
# 0.0

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower_black = np.array([0,0,0])
upper_black = np.array([360,255,50])

mask= cv2.inRange(grid_HSV, lower_black, upper_black)
res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the black part

print("black Part of Image (walls, windows, etc.)")
plt.figure(figsize=(20,8))
plt.imshow(mask)

BLACK_perc = (mask>0).mean()
print(BLACK_perc)
# Out:
# black Part of Image (walls, windows, etc.)
# 0.159541222185564

# %%
grid_HSV = cv2.cvtColor(grid_RGB, cv2.COLOR_RGB2HSV) # Converting to HSV
lower_white = np.array([0,0,168])
upper_white = np.array([172,111,255])

mask= cv2.inRange(grid_HSV, lower_white, upper_white)
res = cv2.bitwise_and(img, img, mask=mask) # Generating image with the white part

print("white Part of Image (walls, windows, etc.)")
plt.figure(figsize=(20,8))
plt.imshow(mask)

WHITE_perc = (mask>0).mean()
print(WHITE_perc)
# Out:
# white Part of Image (walls, windows, etc.)
# 0.0820732064958393
